# %% [markdown]
# # 1. Import libraries

# %%
import numpy as np
import cv2
import os
import matplotlib.pyplot as plt
from tensorflow import keras
import time
import mediapipe as mp

# %% [markdown]
# # 2. Keypoints using MP Holistic

# %%
mp_holistic = mp.solutions.holistic # Holistic model
mp_drawing = mp.solutions.drawing_utils # Drawing utilities

# %%
def mediapipe_detection(image, model):
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB) # COLOR CONVERSION BGR 2 RGB
    image.flags.writeable = False                  # Image is no longer writeable
    results = model.process(image)                 # Make prediction
    image.flags.writeable = True                   # Image is now writeable 
    image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR) # COLOR COVERSION RGB 2 BGR
    return image, results

# %%
def draw_landmarks(image, results):
    mp_drawing.draw_landmarks(image, results.face_landmarks, mp_holistic.FACEMESH_TESSELATION) # Draw face connections
    mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_holistic.POSE_CONNECTIONS) # Draw pose connections
    mp_drawing.draw_landmarks(image, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS) # Draw left hand connections
    mp_drawing.draw_landmarks(image, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS) # Draw right hand connections

# %%
def draw_styled_landmarks(image, results):
    # Draw face connections
    mp_drawing.draw_landmarks(image, results.face_landmarks, mp_holistic.FACEMESH_TESSELATION, 
                             mp_drawing.DrawingSpec(color=(80,110,10), thickness=1, circle_radius=1), 
                             mp_drawing.DrawingSpec(color=(80,256,121), thickness=1, circle_radius=1)
                             ) 
    # Draw pose connections
    mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_holistic.POSE_CONNECTIONS,
                             mp_drawing.DrawingSpec(color=(80,22,10), thickness=2, circle_radius=4), 
                             mp_drawing.DrawingSpec(color=(80,44,121), thickness=2, circle_radius=2)
                             ) 
    # Draw left hand connections
    mp_drawing.draw_landmarks(image, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                             mp_drawing.DrawingSpec(color=(121,22,76), thickness=2, circle_radius=4), 
                             mp_drawing.DrawingSpec(color=(121,44,250), thickness=2, circle_radius=2)
                             ) 
    # Draw right hand connections  
    mp_drawing.draw_landmarks(image, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                             mp_drawing.DrawingSpec(color=(245,117,66), thickness=2, circle_radius=4), 
                             mp_drawing.DrawingSpec(color=(245,66,230), thickness=2, circle_radius=2)
                             )

# %%
cap = cv2.VideoCapture(0)
# Set mediapipe model 
with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    while cap.isOpened():

        # Read feed
        ret, frame = cap.read()

        # Make detections
        image, results = mediapipe_detection(frame, holistic)
        print(results)
        
        # Draw landmarks
        draw_styled_landmarks(image, results)

        # Show to screen
        cv2.imshow('OpenCV Feed', image)

        # Break gracefully
        if cv2.waitKey(10) & 0xFF == ord('q'):
            break
    cap.release()
    cv2.destroyAllWindows()
# Out:
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>

# %% [markdown]
# # 3. Extract Keypoint Values

# %%
def extract_keypoints(results):
    lh = np.array([[res.x, res.y, res.z] for res in results.left_hand_landmarks.landmark]).flatten() if results.left_hand_landmarks else np.zeros(21*3)
    rh = np.array([[res.x, res.y, res.z] for res in results.right_hand_landmarks.landmark]).flatten() if results.right_hand_landmarks else np.zeros(21*3)
    return np.concatenate([lh, rh])

# %% [markdown]
# # 4. Setup Folders for Collection

# %%
# Path for exported data, numpy arrays
DATA_PATH = os.path.join('Data') 

actions = np.array(['ban dang lam gi', 'ban di dau the', 'ban hieu ngon ngu ky hieu khong', 'ban hoc lop may',
                    'ban khoe khong', 'ban muon gio roi', 'ban phai canh giac', 'ban ten la gi', 'ban tien bo day',
                    'ban trong cau co the', 'bo me toi cung la nguoi Diec', 'cai nay bao nhieu tien', 
                    'cai nay la cai gi', 'cam on', 'cap cuu', 'chuc mung', 'chung toi giao tiep voi nhau bang ngon ngu ky hieu', 
                    'con yeu me', 'cong viec cua ban la gi', 'hen gap lai cac ban', 'mon nay khong ngon', 'toi bi chong mat', 
                    'toi bi cuop', 'toi bi dau dau', 'toi bi dau hong', 'toi bi ket xe', 'toi bi lac', 'toi bi phan biet doi xu', 
                    'toi cam thay rat hoi hop', 'toi cam thay rat vui', 'toi can an sang', 'toi can di ve sinh', 
                    'toi can gap bac si', 'toi can phien dich', 'toi can thuoc', 'toi dang an sang', 'toi dang buon', 
                    'toi dang o ben xe', 'toi dang o cong vien', 'toi dang phai cach ly', 'toi dang phan van', 'toi di sieu thi', 
                    'toi di toi Ha Noi', 'toi doc kem', 'toi khoi benh roi', 'toi khong dem theo tien', 'toi khong hieu', 
                    'toi khong quan tam', 'toi la hoc sinh', 'toi la nguoi Diec', 'toi la tho theu', 'toi lam viec o cua hang', 
                    'toi nham dia chi', 'toi song o Ha Noi', 'toi thay doi bung', 'toi thay nho ban', 'toi thich an mi', 
                    'toi thich phim truyen', 'toi viet kem', 'xin chao'])

# Thirty videos worth of data
no_sequences = 60

# Videos are going to be 60 frames in length
sequence_length = 60

# %%
for action in actions: 
    for sequence in range(no_sequences):
        try: 
            os.makedirs(os.path.join(DATA_PATH, action, str(sequence)))
        except:
            pass

# %% [markdown]
# # 5. Collect Keypoint Values for Training and Testing

# %%
# cap = cv2.VideoCapture(0)
# # Set mediapipe model 
# with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    
#     # NEW LOOP
#     # Loop through actions
#     for action in actions:
#         # Loop through sequences aka videos
#         for sequence in range(no_sequences):
#             # Loop through video length aka sequence length
#             for frame_num in range(sequence_length):

#                 # Read feed
#                 ret, frame = cap.read()

#                 # Make detections
#                 image, results = mediapipe_detection(frame, holistic)

#                 # Draw landmarks
#                 draw_styled_landmarks(image, results)
                
#                 # NEW Apply wait logic
#                 if frame_num == 0: 
#                     cv2.putText(image, 'STARTING COLLECTION', (120,200), 
#                                cv2.FONT_HERSHEY_SIMPLEX, 1, (0,255, 0), 4, cv2.LINE_AA)
#                     cv2.putText(image, 'Collecting frames for {} Video Number {}'.format(action, sequence), (15,12), 
#                                cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 255), 1, cv2.LINE_AA)
#                     # Show to screen
#                     cv2.imshow('OpenCV Feed', image)
#                     cv2.waitKey(500)
#                 else: 
#                     cv2.putText(image, 'Collecting frames for {} Video Number {}'.format(action, sequence), (15,12), 
#                                cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 255), 1, cv2.LINE_AA)
#                     # Show to screen
#                     cv2.imshow('OpenCV Feed', image)
                
#                 # NEW Export keypoints
#                 keypoints = extract_keypoints(results)
#                 npy_path = os.path.join(DATA_PATH, action, str(sequence), str(frame_num))
#                 np.save(npy_path, keypoints)

#                 # Break gracefully
#                 if cv2.waitKey(10) & 0xFF == ord('q'):
#                     break
                    
#     cap.release()
#     cv2.destroyAllWindows()

# %% [markdown]
# # 6. Preprocess Data and Create Labels and Features

# %%
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical

# %%
label_map = {label:num for num, label in enumerate(actions)}

# %%
label_map
# Out:
# {'ban dang lam gi': 0,
#  'ban di dau the': 1,
#  'ban hieu ngon ngu ky hieu khong': 2,
#  'ban hoc lop may': 3,
#  'ban khoe khong': 4,
#  'ban muon gio roi': 5,
#  'ban phai canh giac': 6,
#  'ban ten la gi': 7,
#  'ban tien bo day': 8,
#  'ban trong cau co the': 9,
#  'bo me toi cung la nguoi Diec': 10,
#  'cai nay bao nhieu tien': 11,
#  'cai nay la cai gi': 12,
#  'cam on': 13,
#  'cap cuu': 14,
#  'chuc mung': 15,
#  'chung toi giao tiep voi nhau bang ngon ngu ky hieu': 16,
#  'con yeu me': 17,
#  'cong viec cua ban la gi': 18,
#  'hen gap lai cac ban': 19,
#  'mon nay khong ngon': 20,
#  'toi bi chong mat': 21,
#  'toi bi cuop': 22,
#  'toi bi dau dau': 23,
#  'toi bi dau hong': 24,
#  'toi bi ket xe': 25,
#  'toi bi lac': 26,
#  'toi bi phan biet doi xu': 27,
#  'toi cam thay rat hoi hop': 28,
#  'toi cam thay rat vui': 29,
#  'toi can an sang': 30,
#  'toi can di ve sinh': 31,
#  'toi can gap bac si': 32,
#  'toi can phien dich': 33,
#  'toi can thuoc': 34,
#  'toi dang an sang': 35,
#  'toi dang buon': 36,
#  'toi dang o ben xe': 37,
#  'toi dang o cong vien': 38,
#  'toi dang phai cach ly': 39,
#  'toi dang phan van': 40,
#  'toi di sieu thi': 41,
#  'toi di toi Ha Noi': 42,
#  'toi doc kem': 43,
#  'toi khoi benh roi': 44,
#  'toi khong dem theo tien': 45,
#  'toi khong hieu': 46,
#  'toi khong quan tam': 47,
#  'toi la hoc sinh': 48,
#  'toi la nguoi Diec': 49,
#  'toi la tho theu': 50,
#  'toi lam viec o cua hang': 51,
#  'toi nham dia chi': 52,
#  'toi song o Ha Noi': 53,
#  'toi thay doi bung': 54,
#  'toi thay nho ban': 55,
#  'toi thich an mi': 56,
#  'toi thich phim truyen': 57,
#  'toi viet kem': 58,
#  'xin chao': 59}

# %%
sequences, labels = [], []
for action in actions:
    for sequence in range(no_sequences):
        window = []
        for frame_num in range(sequence_length):
            res = np.load(os.path.join(DATA_PATH, action, str(sequence), "{}.npy".format(frame_num)))
            window.append(res)
        sequences.append(window)
        labels.append(label_map[action])

# %%
actions.shape[0]
# Out:
# 60

# %%
np.array(sequences).shape
# Out:
# (3600, 60, 126)

# %%
np.array(labels).shape
# Out:
# (3600,)

# %%
X = np.array(sequences)

# %%
X.shape
# Out:
# (3600, 60, 126)

# %%
y = to_categorical(labels).astype(int)

# %%
y.shape
# Out:
# (3600, 60)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %% [markdown]
# # 7. Build and Train LSTM Neural Network

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
from tensorflow.keras.callbacks import TensorBoard

# %%
log_dir = os.path.join('Logs')
tb_callback = TensorBoard(log_dir=log_dir)

# %%
model = Sequential()
model.add(LSTM(64, return_sequences=True, activation='relu', input_shape=(60,126))) # 64
model.add(LSTM(128, return_sequences=True, activation='relu'))
model.add(LSTM(64, return_sequences=False, activation='relu'))
model.add(Dense(64, activation='relu'))
model.add(Dense(32, activation='relu'))
model.add(Dense(actions.shape[0], activation='softmax'))

# %%
model.compile(optimizer='Adam', loss='categorical_crossentropy', metrics=['categorical_accuracy'])

# %%
model.fit(X_train, y_train, epochs=100, callbacks=[tb_callback]) #train model
# Out:
# Epoch 1/100
# 90/90 [==============================] - 13s 72ms/step - loss: 4.0946 - categorical_accuracy: 0.0236
# Epoch 2/100
# 90/90 [==============================] - 7s 72ms/step - loss: 4.0758 - categorical_accuracy: 0.0264
# Epoch 3/100
# 90/90 [==============================] - 7s 72ms/step - loss: 3.9821 - categorical_accuracy: 0.0306
# Epoch 4/100
# 90/90 [==============================] - 7s 73ms/step - loss: 3.8294 - categorical_accuracy: 0.0354
# Epoch 5/100
# 90/90 [==============================] - 7s 77ms/step - loss: 3.8458 - categorical_accuracy: 0.0368
# Epoch 6/100
# 90/90 [==============================] - 8s 85ms/step - loss: 3.3999 - categorical_accuracy: 0.0677
# Epoch 7/100
# 90/90 [==============================] - 8s 94ms/step - loss: 3.2705 - categorical_accuracy: 0.0858
# Epoch 8/100
# 90/90 [==============================] - 9s 96ms/step - loss: 3.1151 - categorical_accuracy: 0.1198
# Epoch 9/100
# 90/90 [==============================] - 8s 93ms/step - loss: 3.3013 - categorical_accuracy: 0.1306
# Epoch 10/100
# 90/90 [==============================] - 8s 84ms/step - loss: 2.9709 - categorical_accuracy: 0.1448
# Epoch 11/100
# 90/90 [==============================] - 8s 94ms/step - loss: 2.6702 - categorical_accuracy: 0.2035
# Epoch 12/100
# 90/90 [==============================] - 8s 85ms/step - loss: 2.4867 - categorical_accuracy: 0.2306
# Epoch 13/100
# 90/90 [==============================] - 8s 85ms/step - loss: 2.2848 - categorical_accuracy: 0.2778
# Epoch 14/100
# 90/90 [==============================] - 8s 87ms/step - loss: 3.6376 - categorical_accuracy: 0.1295
# Epoch 15/100
# 90/90 [==============================] - 9s 97ms/step - loss: 2.7944 - categorical_accuracy: 0.1705
# Epoch 16/100
# 90/90 [==============================] - 7s 81ms/step - loss: 2.3526 - categorical_accuracy: 0.2594
# Epoch 17/100
# 90/90 [==============================] - 7s 80ms/step - loss: 2.1409 - categorical_accuracy: 0.3222
# Epoch 18/100
# 90/90 [==============================] - 7s 80ms/step - loss: 2.0089 - categorical_accuracy: 0.3733
# Epoch 19/100
# 90/90 [==============================] - 7s 80ms/step - loss: 1.8966 - categorical_accuracy: 0.3986
# Epoch 20/100
# 90/90 [==============================] - 7s 80ms/step - loss: 1.7657 - categorical_accuracy: 0.4441
# Epoch 21/100
# 90/90 [==============================] - 7s 81ms/step - loss: 1.6225 - categorical_accuracy: 0.4736
# Epoch 22/100
# 90/90 [==============================] - 7s 80ms/step - loss: 1.4797 - categorical_accuracy: 0.5181
# Epoch 23/100
# 90/90 [==============================] - 8s 90ms/step - loss: 1.4258 - categorical_accuracy: 0.5351
# Epoch 24/100
# 90/90 [==============================] - 8s 86ms/step - loss: 1.3550 - categorical_accuracy: 0.5510
# Epoch 25/100
# 90/90 [==============================] - 9s 105ms/step - loss: 1.2565 - categorical_accuracy: 0.5872
# Epoch 26/100
# 90/90 [==============================] - 9s 102ms/step - loss: 1.1312 - categorical_accuracy: 0.6233
# Epoch 27/100
# 90/90 [==============================] - 9s 105ms/step - loss: 1.1795 - categorical_accuracy: 0.6215
# Epoch 28/100
# 90/90 [==============================] - 8s 88ms/step - loss: 1.1107 - categorical_accuracy: 0.6257
# Epoch 29/100
# 90/90 [==============================] - 8s 89ms/step - loss: 1.0023 - categorical_accuracy: 0.6698
# Epoch 30/100
# 90/90 [==============================] - 8s 86ms/step - loss: 0.8927 - categorical_accuracy: 0.7024
# Epoch 31/100
# 90/90 [==============================] - 8s 87ms/step - loss: 0.8713 - categorical_accuracy: 0.7122
# Epoch 32/100
# 90/90 [==============================] - 9s 95ms/step - loss: 0.7809 - categorical_accuracy: 0.7465
# Epoch 33/100
# 90/90 [==============================] - 8s 86ms/step - loss: 0.7544 - categorical_accuracy: 0.7441
# Epoch 34/100
# 90/90 [==============================] - 8s 89ms/step - loss: 0.6695 - categorical_accuracy: 0.7844
# Epoch 35/100
# 90/90 [==============================] - 8s 90ms/step - loss: 0.8664 - categorical_accuracy: 0.7358
# Epoch 36/100
# 90/90 [==============================] - 8s 87ms/step - loss: 0.5941 - categorical_accuracy: 0.8066
# Epoch 37/100
# 90/90 [==============================] - 8s 86ms/step - loss: 0.6002 - categorical_accuracy: 0.7920
# Epoch 38/100
# 90/90 [==============================] - 7s 83ms/step - loss: 0.5805 - categorical_accuracy: 0.8111
# Epoch 39/100
# 90/90 [==============================] - 8s 92ms/step - loss: 0.5894 - categorical_accuracy: 0.8017
# Epoch 40/100
# 90/90 [==============================] - 8s 85ms/step - loss: 0.4428 - categorical_accuracy: 0.8514
# Epoch 41/100
# 90/90 [==============================] - 8s 90ms/step - loss: 0.4503 - categorical_accuracy: 0.8483
# Epoch 42/100
# 90/90 [==============================] - 8s 88ms/step - loss: 1.2263 - categorical_accuracy: 0.6955
# Epoch 43/100
# 90/90 [==============================] - 8s 89ms/step - loss: 1.0779 - categorical_accuracy: 0.6493
# Epoch 44/100
# 90/90 [==============================] - 8s 92ms/step - loss: 0.6486 - categorical_accuracy: 0.7851
# Epoch 45/100
# 90/90 [==============================] - 8s 88ms/step - loss: 0.5089 - categorical_accuracy: 0.8309
# Epoch 46/100
# 90/90 [==============================] - 9s 100ms/step - loss: 0.6860 - categorical_accuracy: 0.7868
# Epoch 47/100
# 90/90 [==============================] - 8s 92ms/step - loss: 0.6440 - categorical_accuracy: 0.7889
# Epoch 48/100
# 90/90 [==============================] - 8s 93ms/step - loss: 0.4134 - categorical_accuracy: 0.8562
# Epoch 49/100
# 90/90 [==============================] - 9s 100ms/step - loss: 0.3336 - categorical_accuracy: 0.8889
# Epoch 50/100
# 90/90 [==============================] - 9s 100ms/step - loss: 0.3407 - categorical_accuracy: 0.8885
# Epoch 51/100
# 90/90 [==============================] - 9s 97ms/step - loss: 0.3064 - categorical_accuracy: 0.8913
# Epoch 52/100
# 90/90 [==============================] - 9s 97ms/step - loss: 0.2698 - categorical_accuracy: 0.9042
# Epoch 53/100
# 90/90 [==============================] - 8s 87ms/step - loss: 0.2846 - categorical_accuracy: 0.9118
# Epoch 54/100
# 90/90 [==============================] - 8s 88ms/step - loss: 0.3113 - categorical_accuracy: 0.9014
# Epoch 55/100
# 90/90 [==============================] - 8s 90ms/step - loss: 0.2401 - categorical_accuracy: 0.9181
# Epoch 56/100
# 90/90 [==============================] - 8s 86ms/step - loss: 0.2435 - categorical_accuracy: 0.9184
# Epoch 57/100
# 90/90 [==============================] - 8s 90ms/step - loss: 0.1810 - categorical_accuracy: 0.9378
# Epoch 58/100
# 90/90 [==============================] - 8s 94ms/step - loss: 0.3295 - categorical_accuracy: 0.8917
# Epoch 59/100
# 90/90 [==============================] - 8s 94ms/step - loss: 0.1978 - categorical_accuracy: 0.9312
# Epoch 60/100
# 90/90 [==============================] - 9s 99ms/step - loss: 0.2098 - categorical_accuracy: 0.9288
# Epoch 61/100
# 90/90 [==============================] - 9s 96ms/step - loss: 0.2140 - categorical_accuracy: 0.9278
# Epoch 62/100
# 90/90 [==============================] - 8s 87ms/step - loss: 0.1581 - categorical_accuracy: 0.9566
# Epoch 63/100
# 90/90 [==============================] - 8s 91ms/step - loss: 0.1322 - categorical_accuracy: 0.9590
# Epoch 64/100
# 90/90 [==============================] - 8s 89ms/step - loss: 0.1399 - categorical_accuracy: 0.9542
# Epoch 65/100
# 90/90 [==============================] - 8s 86ms/step - loss: 0.1416 - categorical_accuracy: 0.9528
# Epoch 66/100
# 90/90 [==============================] - 8s 93ms/step - loss: 0.2035 - categorical_accuracy: 0.9340
# Epoch 67/100
# 90/90 [==============================] - 8s 92ms/step - loss: 0.2051 - categorical_accuracy: 0.9316
# Epoch 68/100
# 90/90 [==============================] - 8s 92ms/step - loss: 0.0850 - categorical_accuracy: 0.9760
# Epoch 69/100
# 90/90 [==============================] - 9s 100ms/step - loss: 0.0668 - categorical_accuracy: 0.9802
# Epoch 70/100
# 90/90 [==============================] - 8s 90ms/step - loss: 0.1190 - categorical_accuracy: 0.9688
# Epoch 71/100
# 90/90 [==============================] - 8s 90ms/step - loss: 0.3341 - categorical_accuracy: 0.8986
# Epoch 72/100
# 90/90 [==============================] - 8s 89ms/step - loss: 0.1050 - categorical_accuracy: 0.9722
# Epoch 73/100
# 90/90 [==============================] - 8s 88ms/step - loss: 0.0580 - categorical_accuracy: 0.9844
# Epoch 74/100
# 90/90 [==============================] - 8s 94ms/step - loss: 0.0768 - categorical_accuracy: 0.9788
# Epoch 75/100
# 90/90 [==============================] - 11s 119ms/step - loss: 0.0778 - categorical_accuracy: 0.9823
# Epoch 76/100
# 90/90 [==============================] - 10s 112ms/step - loss: 0.1202 - categorical_accuracy: 0.9618
# Epoch 77/100
# 90/90 [==============================] - 9s 100ms/step - loss: 0.2550 - categorical_accuracy: 0.9208
# Epoch 78/100
# 90/90 [==============================] - 8s 87ms/step - loss: 0.1285 - categorical_accuracy: 0.9611
# Epoch 79/100
# 90/90 [==============================] - 9s 102ms/step - loss: 0.0731 - categorical_accuracy: 0.9809
# Epoch 80/100
# 90/90 [==============================] - 8s 94ms/step - loss: 0.0405 - categorical_accuracy: 0.9889
# Epoch 81/100
# 90/90 [==============================] - 8s 88ms/step - loss: 0.0329 - categorical_accuracy: 0.9913
# Epoch 82/100
# 90/90 [==============================] - 8s 92ms/step - loss: 0.8506 - categorical_accuracy: 0.7969
# Epoch 83/100
# 90/90 [==============================] - 9s 99ms/step - loss: 0.1933 - categorical_accuracy: 0.9444
# Epoch 84/100
# 90/90 [==============================] - 8s 92ms/step - loss: 0.1017 - categorical_accuracy: 0.9726
# Epoch 85/100
# 90/90 [==============================] - 9s 105ms/step - loss: 0.0867 - categorical_accuracy: 0.9747
# Epoch 86/100
# 90/90 [==============================] - 10s 114ms/step - loss: 0.0581 - categorical_accuracy: 0.9847
# Epoch 87/100
# 90/90 [==============================] - 10s 113ms/step - loss: 0.0460 - categorical_accuracy: 0.9878
# Epoch 88/100
# 90/90 [==============================] - 9s 104ms/step - loss: 0.0322 - categorical_accuracy: 0.9927
# Epoch 89/100
# 90/90 [==============================] - 10s 112ms/step - loss: 0.0618 - categorical_accuracy: 0.9844
# Epoch 90/100
# 90/90 [==============================] - 10s 114ms/step - loss: 0.1242 - categorical_accuracy: 0.9573
# Epoch 91/100
# 90/90 [==============================] - 11s 119ms/step - loss: 0.1097 - categorical_accuracy: 0.9677
# Epoch 92/100
# 90/90 [==============================] - 11s 116ms/step - loss: 0.0941 - categorical_accuracy: 0.9736
# Epoch 93/100
# 90/90 [==============================] - 10s 108ms/step - loss: 0.0688 - categorical_accuracy: 0.9799
# Epoch 94/100
# 90/90 [==============================] - 9s 100ms/step - loss: 0.1367 - categorical_accuracy: 0.9587
# Epoch 95/100
# 90/90 [==============================] - 10s 106ms/step - loss: 0.0988 - categorical_accuracy: 0.9694
# Epoch 96/100
# 90/90 [==============================] - 9s 96ms/step - loss: 0.0377 - categorical_accuracy: 0.9920
# Epoch 97/100
# 90/90 [==============================] - 10s 114ms/step - loss: 0.0122 - categorical_accuracy: 0.9990
# Epoch 98/100
# 90/90 [==============================] - 10s 110ms/step - loss: 0.0040 - categorical_accuracy: 1.0000
# Epoch 99/100
# 90/90 [==============================] - 9s 103ms/step - loss: 0.0025 - categorical_accuracy: 1.0000
# Epoch 100/100
# 90/90 [==============================] - 8s 93ms/step - loss: 0.0020 - categorical_accuracy: 1.0000

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_6 (LSTM)               (None, 60, 64)            48896
#
#  lstm_7 (LSTM)               (None, 60, 128)           98816
#
#  lstm_8 (LSTM)               (None, 64)                49408
#
#  dense_6 (Dense)             (None, 64)                4160
#
#  dense_7 (Dense)             (None, 32)                2080
#
#  dense_8 (Dense)             (None, 60)                1980
#
# =================================================================
# Total params: 205,340
# Trainable params: 205,340
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # 8. Save Weights

# %%
model.save('action.h5')

# %%
del model

# %%
model = keras.models.load_model('action.h5')

# %% [markdown]
# # 9. Evaluation using Confusion Matrix and Accuracy

# %%
from sklearn.metrics import multilabel_confusion_matrix, accuracy_score

# %%
yhat = model.predict(X_test)
# Out:
# 23/23 [==============================] - 1s 34ms/step

# %%
ytrue = np.argmax(y_test, axis=1).tolist()
yhat = np.argmax(yhat, axis=1).tolist()

# %%
multilabel_confusion_matrix(ytrue, yhat)
# Out:
# array([[[707,   0],
#         [  2,  11]],
#
#        [[703,   6],
#         [  1,  10]],
#
#        [[713,   0],
#         [  0,   7]],
#
#        [[709,   1],
#         [  0,  10]],
#
#        [[711,   0],
#         [  1,   8]],
#
#        [[703,   0],
#         [  1,  16]],
#
#        [[700,   2],
#         [  3,  15]],
#
#        [[702,   4],
#         [  0,  14]],
#
#        [[704,   0],
#         [  2,  14]],
#
#        [[707,   4],
#         [  1,   8]],
#
#        [[705,   3],
#         [  1,  11]],
#
#        [[700,   3],
#         [  3,  14]],
#
#        [[707,   2],
#         [  3,   8]],
#
#        [[708,   0],
#         [  1,  11]],
#
#        [[707,   0],
#         [  0,  13]],
#
#        [[708,   0],
#         [  3,   9]],
#
#        [[709,   2],
#         [  1,   8]],
#
#        [[707,   1],
#         [  1,  11]],
#
#        [[703,   1],
#         [  3,  13]],
#
#        [[710,   1],
#         [  1,   8]],
#
#        [[705,   1],
#         [  6,   8]],
#
#        [[708,   2],
#         [  2,   8]],
#
#        [[709,   2],
#         [  1,   8]],
#
#        [[708,   0],
#         [  0,  12]],
#
#        [[705,   2],
#         [  3,  10]],
#
#        [[715,   1],
#         [  0,   4]],
#
#        [[710,   1],
#         [  0,   9]],
#
#        [[707,   0],
#         [  1,  12]],
#
#        [[704,   0],
#         [  0,  16]],
#
#        [[710,   1],
#         [  1,   8]],
#
#        [[708,   0],
#         [  0,  12]],
#
#        [[705,   3],
#         [  1,  11]],
#
#        [[714,   1],
#         [  0,   5]],
#
#        [[700,   2],
#         [  2,  16]],
#
#        [[712,   2],
#         [  1,   5]],
#
#        [[702,   0],
#         [  1,  17]],
#
#        [[706,   1],
#         [  0,  13]],
#
#        [[710,   1],
#         [  0,   9]],
#
#        [[704,   0],
#         [  0,  16]],
#
#        [[706,   0],
#         [  2,  12]],
#
#        [[704,   3],
#         [  0,  13]],
#
#        [[711,   0],
#         [  0,   9]],
#
#        [[706,   0],
#         [  0,  14]],
#
#        [[709,   3],
#         [  0,   8]],
#
#        [[707,   2],
#         [  1,  10]],
#
#        [[710,   0],
#         [  1,   9]],
#
#        [[706,   3],
#         [  1,  10]],
#
#        [[709,   0],
#         [  0,  11]],
#
#        [[709,   0],
#         [  3,   8]],
#
#        [[701,   3],
#         [  4,  12]],
#
#        [[711,   0],
#         [  1,   8]],
#
#        [[703,   1],
#         [  0,  16]],
#
#        [[710,   0],
#         [  0,  10]],
#
#        [[706,   1],
#         [  2,  11]],
#
#        [[705,   3],
#         [  3,   9]],
#
#        [[706,   1],
#         [  1,  12]],
#
#        [[709,   0],
#         [  1,  10]],
#
#        [[708,   1],
#         [  1,  10]],
#
#        [[696,   1],
#         [  3,  20]],
#
#        [[711,   0],
#         [  1,   8]]], dtype=int64)

# %%
accuracy_score(ytrue, yhat)
# Out:
# 0.9
